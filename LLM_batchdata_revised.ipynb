# %%
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
# from langchain_anthropic import ChatAnthropic
# from langchain_core.output_parsers import StrOutputParser
import csv
import os
import pandas as pd
import re

# %%
api = 'sk-proj'# use your own keys

system_message = """
You are an expert in NMR spectroscopy and organic chemistry.
"""

user_prompt = """
Here are the peaks from the HNMR spectrum: {spectrum_HNMR}, and peaks from the CNMR spectrum: {spectrum_CNMR}.
The chemical formula is {chemical_formula}. What's the molecule name? 
Think step-by-step, making extensive use of a scratchpad to record your thoughts. Consider finding ways to group related peaks 
together, and keep track of the stoichiometry and the amount of unassigned H atoms as you make provisional assignments.
Please solely look at the HNMR to determine molecule.
Format the final answer like this - 
### Scratchpad ### <scratchpad> ### Scratchpad ###
### Start answer ### <prediction> ### End answer ###
The prediction should only contain the name of the molecule and no other text
"""

# %%
# Path to the folder containing the files
folder_path = 'csvfiles_update'

# Dictionary to store HNMR and CNMR data for each CAS number
cas_data = {}

# Iterate over the filenames in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('_HNMR.csv'):
        # Extract CAS number and chemical formula from the filename
        parts = filename.split('_')
        cas_number = parts[0]
        chemical_formula = parts[1]
        
        # Read HNMR spectrum data from the file
        with open(os.path.join(folder_path, filename), 'r') as csvfile:
            csvreader = csv.reader(csvfile)
            next(csvreader)  # Skip header
            
            data_string_hnmr = ""
              
            for row in csvreader:
                row_string = ", ".join(row)
                data_string_hnmr += row_string + "\n"
                
        # Find corresponding CNMR file
        cnmr_filename = filename.replace('HNMR', 'CNMR')
        cnmr_path = os.path.join(folder_path, cnmr_filename)
        if not os.path.exists(cnmr_path):
            continue
            
        # Read CNMR spectrum data from the file
        with open(cnmr_path, 'r') as csvfile:
            csvreader = csv.reader(csvfile)
            next(csvreader)  # Skip header
            
            data_string_cnmr = ""
              
            for row in csvreader:
                row_string = ", ".join(row)
                data_string_cnmr += row_string + "\n"
        
       # Add HNMR and CNMR data to the dictionary
        if cas_number in cas_data:
            cas_data[cas_number]['spectrum_HNMR'] += data_string_hnmr
            cas_data[cas_number]['spectrum_CNMR'] += data_string_cnmr
        else:
            cas_data[cas_number] = {
                'spectrum_HNMR': data_string_hnmr, 
                'spectrum_CNMR': data_string_cnmr,
                'chemical_formula': chemical_formula  # Ensure chemical formula is stored
            }

# List to store the results
results = []

def call_openAI(spec_data1, spec_data2, chem_formula, system_message=system_message, user_prompt=user_prompt, 
             api_key = api,
             model = "gpt-4-0613"):
             #"gpt-3.5-turbo"):

    llm = ChatOpenAI(api_key=api_key, model = model)

    prompt = ChatPromptTemplate.from_messages([
    ("system", system_message),
    ("user", user_prompt)])

    llm = ChatOpenAI(api_key=api_key, model=model)

    parser = StrOutputParser()
    
    chain = prompt | llm | parser

    llm_output = chain.invoke({"spectrum_HNMR": spec_data1, "spectrum_CNMR": spec_data2,  "chemical_formula": chem_formula})
    return llm_output

# Iterate over the CAS numbers and call the OpenAI API
for cas_number, data in cas_data.items():
    output = call_openAI(spec_data1=data['spectrum_HNMR'],  spec_data2=data['spectrum_CNMR'],
                         chem_formula = data['chemical_formula'])
    results.append((cas_number, output))

# Create a DataFrame from the results
df = pd.DataFrame(results, columns=['cas_number', 'guess'])

# %%
import re

# Define a function to extract the guess answer
def extract_guess_answer(x):
    match = re.search(r'### Start answer ###\s*(.*?)\s*### End answer ###', x)
    if match:
        return match.group(1)
    else:
        return None  # or any other fallback value you prefer

# Apply the function to create a new column 'guess_answer'
df['guess_answer'] = df['guess'].apply(extract_guess_answer)

# Display the DataFrame with the new 'guess_answer' column
print(df)
# Out:
#     cas_number                                              guess  \
# 0     105-53-3  ### Scratchpad ###\n\nThe molecule is C7H14O2,...
# 1   13475-82-6  ### Scratchpad ### \n\nConsidering the chemica...
# 2      93-58-3  ### Scratchpad ### \n\nThe chemical formula C8...
# 3      52-52-8  ### Scratchpad ###\nThe chemical formula is C6...
# 4      78-78-4  ### Scratchpad ### \nThe chemical formula C5H1...
# 5     591-76-4  ### Scratchpad ### \n\nThe given formula is C7...
# 6     108-38-3  ### Scratchpad ### \nThe molecular formula is ...
# 7     124-19-6  ### Scratchpad ### \nThe chemical formula is C...
# 8     107-83-5  ### Scratchpad ### \nThe chemical formula C6H1...
# 9     540-84-1  ### Scratchpad ### \nGiven the molecular formu...
# 10  22204-53-1  ### Scratchpad ### \nFirstly, taking a look at...
# 11    513-81-5  ### Scratchpad ### \nThe chemical formula is C...
# 12    123-72-8  ### Scratchpad ### \nLooking at the HNMR spect...
# 13    620-02-0  ### Scratchpad ### \nThe chemical formula is C...
# 14  15687-27-1  ### Scratchpad ### \n\nThe chemical formula is...
# 15     79-16-3  ### Scratchpad ### \nThe chemical formula of t...
# 16    123-86-4  ### Scratchpad ### \n\nGiven the chemical form...
# 17     93-56-1  ### Scratchpad ### \n1. Note that the chemical...
#
#                   guess_answer
# 0             Butyl propionate
# 1                     Dodecane
# 2                p-Toluic acid
# 3   2,2,4-Trimethylpentanamide
# 4                      Pentane
# 5        2,2,3-trimethylbutane
# 6                     m-Xylene
# 7                      Nonanol
# 8                       Hexane
# 9                       Octane
# 10   2-Phenylprop-2-enoic acid
# 11          1,3-Cyclohexadiene
# 12             Tetrahydrofuran
# 13               p-Toluic acid
# 14       2-phenylethyl acetate
# 15                 Benzanilide
# 16              Pentanoic acid
# 17               Phenylacetate

# %%
df['guess'].values
# Out:
# array(['### Scratchpad ###\n\nThe molecule is C7H14O2, which indicates that there is likely an ester or carboxylic acid functional group present due to the presence of an oxygen atom. The CNMR spectrum shows 4 unique carbon environments, meaning that there is symmetry in the molecule. The most deshielded carbon at 166.64 ppm is likely a carbonyl carbon.\n\nLooking at the HNMR spectrum, there are four distinct sets of protons. The most deshielded set at 4.242, 4.218, 4.194, and 4.171 ppm are likely the protons next to the carbonyl group. The set of protons at 3.361 ppm could be the protons next to an oxygen atom. The two sets of protons at 1.309 and 1.285 ppm are likely the protons on the rest of the carbon chain.\n\nThe molecular formula C7H14O2 also suggests that there might be a CH3 group (since the number of hydrogens is even), which could correspond to the highest peak in the HNMR spectrum at 1.285 ppm.\n\nTaking all this into account, the molecule could be an ester with a four-carbon chain and a three-carbon chain attached to the ester group. This would be consistent with the symmetry suggested by the CNMR and the molecular formula.\n\n### Scratchpad ###\n\n### Start answer ### Butyl propionate ### End answer ###',
#        "### Scratchpad ### \n\nConsidering the chemical formula C12H26 and the provided HNMR data, it's clear that this is an alkane because there are no signals in the region where you'd expect protons attached to carbon-carbon double bonds, carbon-oxygen double bonds, or aromatic rings. \n\nWith the formula of C12H26, this suggests that the molecule is possibly a dodecane. \n\nThe number of protons in the molecule is 26, and looking at the HNMR data, there are 5 different peaks, which represent 5 different types of protons. \n\nLet's look at the chemical shifts and the area under each peak, which represents the number of protons. \n\nPeak 1: 109.13 Hz, 1.219 ppm, 32 protons\nPeak 2: 105.44 Hz, 1.178 ppm, 24 protons\nPeak 3: 103.75 Hz, 1.159 ppm, 43 protons\nPeak 4: 88.19 Hz, 0.985 ppm, 71 protons\nPeak 5: 80.88 Hz, 0.904 ppm, 1000 protons\n\nThe chemical shifts are all in the range between 0.9-1.2 ppm, this is the typical range for alkanes. \n\nThe peak with the largest area under the curve corresponds to the most abundant type of proton in the molecule, which are 1000 protons at 0.904 ppm. This is likely due to the fact that dodecane is a straight chain alkane, and the majority of the protons are identical and are not near any functional groups that would cause their chemical shift to change significantly. \n\nThe other peaks represent different types of protons that are slightly different due to their position in the molecule. For example, the protons at the ends of the molecule are different from those in the middle. \n\nThe peak at 1.219 ppm with 32 protons and the peak at 1.178 ppm with 24 protons likely correspond to the protons at the ends of the chain. \n\nThe peak at 1.159 ppm with 43 protons likely represents the protons in the middle of the chain. \n\nThe peak at 0.985 ppm with 71 protons likely represents the protons next to the ends of the chain. \n\nConsidering all this, the molecule can be identified as dodecane. \n\n### Start answer ### Dodecane ### End answer ###",
#        '### Scratchpad ### \n\nThe chemical formula C8H8O2 indicates that there should be 8 carbons, 8 hydrogens, and 2 oxygens. \n\nLooking at the HNMR spectrum, we can see that there are multiple peaks in the aromatic region (around 7-8 ppm), which suggests the presence of an aromatic ring. \n\nThe integration of these peaks suggests that there are 5 hydrogen atoms in the aromatic region, which means there should be a monosubstituted benzene ring in the molecule (as a monosubstituted benzene ring has 5 hydrogens). \n\nThe remaining 3 hydrogens are likely a part of a methyl group (CH3), as there is a peak at 3.885 ppm with an integration of 1000, which suggests the presence of 3 equivalent protons in a non-aromatic environment.\n\nThe CNMR peaks at 167.04 ppm and 52.01 ppm suggest the presence of a carbonyl group (C=O) and a carbon attached to an oxygen, respectively. \n\nBased on the evidence, it seems like we have a monosubstituted benzene ring with a carbonyl group (C=O) and a methyl group (CH3) attached to it, which fits with the chemical formula C8H8O2. \n\nThe most common structure that fits these criteria and the provided NMR spectra is p-toluic acid, which is a monosubstituted benzene ring with a carboxylic acid group (-COOH) and a methyl group (-CH3) attached to it. \n\n### Scratchpad ###\n\n### Start answer ### \n\np-Toluic acid\n\n### End answer ###',
#        "### Scratchpad ###\nThe chemical formula is C6H11NO2. Let's try to analyze the HNMR spectrum first.\n\nThe integration of the peaks can give us the number of equivalent protons contributing to each peak.\n\nFrom the HNMR data, it seems that there are two distinct groups of peaks. One group is around 2.2 ppm and the other is around 1.85 ppm. \n\nThe chemical shift of the peaks around 2.2 ppm is characteristic of protons attached to a carbon that is adjacent to a carbonyl group. The integration of these peaks sums up to around 2595, which is not a whole number. However, considering experimental errors, these protons are most likely equivalent and their total number is probably 3 (the closest whole number).\n\nThe peaks around 1.85 ppm have a total integration of around 6635, which is also not a whole number. But again, if we account for experimental errors, this could suggest the presence of 8 equivalent protons.\n\nTherefore, according to the HNMR data, we have 3 protons adjacent to a carbonyl group and 8 protons that are equivalent but not necessarily adjacent to a carbonyl group. This leaves us with no unassigned protons, which fits with the chemical formula.\n\nConsidering this and the chemical formula, the molecule could be 2,2,4-Trimethylpentanamide.\n### Scratchpad ###\n\n### Start answer ### \n2,2,4-Trimethylpentanamide\n### End answer ###",
#        '### Scratchpad ### \nThe chemical formula C5H12 corresponds to a pentane structure. Considering the number of hydrogens and the peaks in the HNMR spectrum, we can assign the peaks as follows:\n \n- The peak at 113.94 Hz, 1.273 ppm corresponds to 3 hydrogens on a methyl group (CH3).\n- The peak at 107.38 Hz, 1.199 ppm corresponds to 2 hydrogens on a methylene group (CH2).\n- The peak at 106.31 Hz, 1.188 ppm corresponds to 2 hydrogens on a methylene group (CH2).\n- The peak at 101.75 Hz, 1.137 ppm corresponds to 2 hydrogens on a methylene group (CH2).\n- The peak at 100.75 Hz, 1.125 ppm corresponds to 3 hydrogens on a methyl group (CH3).\n\nThis interpretation fits with the chemical formula C5H12 and suggests a linear pentane structure with no branching or unsaturation. The peaks do not show any significant chemical shift that would suggest the presence of functional groups or aromatic rings. \n\n### Start answer ### Pentane ### End answer ###',
#        "### Scratchpad ### \n\nThe given formula is C7H16, which indicates that the molecule is an alkane. This makes sense because the HNMR peaks are all very close together, a characteristic of alkanes where all the hydrogens are chemically similar. \nThere are no peaks in the aromatic or carbonyl region, further supporting that this is an alkane. \n\nThe integration of the HNMR peaks is not very useful in this case because all the hydrogens are equivalent in an alkane. \n\nFrom the formula, we can deduce that the molecule has to be a straight-chain or a branched alkane. From the chemical formula, there is no degree of unsaturation, confirming the absence of any double bonds or rings. \n\nConsidering all these factors, the molecule can be straight-chain heptane or a branched isomer of heptane. \n\nHowever, we know that in the case of straight-chain heptane, there wouldn't be this many peaks in the HNMR. Each type of hydrogen (based on its environment) gives one peak, and heptane has only two types of hydrogens - those at the end of the chain and those in the middle. This would result in two peaks, not the multiple peaks seen here.\n\nSo, the molecule must be a branched isomer of heptane. The only branched isomer of heptane that would give this many peaks is 2,2,3-trimethylbutane.\n\n### Scratchpad ### \n\n### Start answer ### 2,2,3-trimethylbutane ### End answer ###",
#        '### Scratchpad ### \nThe molecular formula is C8H10, which means the molecule is unsaturated. \n\nLooking at the HNMR spectrum, we can see several peaks. Grouping them together, we find:\n\nGroup 1: 113.94 Hz, 1.273 ppm, 3H (methyl group)\nGroup 2: 107.38 Hz, 1.199 ppm, 2H (methylene group)\nGroup 3: 106.31 Hz, 1.188 ppm, 2H (methylene group)\nGroup 4: 101.75 Hz, 1.137 ppm, 3H (methyl group)\n\nThe 13C NMR data show five peaks, which suggests five types of carbon environments in the molecule.\n\nHowever, the prompt asks to only consider the HNMR spectrum for identifying the molecule.\n\nBy observing the hydrogen peaks, we can see that we have two methyl groups and two methylene groups. \n\nConsidering the unsaturation level of the molecule (IHD=1) from the given formula, it indicates the presence of either a ring or a double bond. \n\nThe chemical shifts of hydrogen atoms also suggest that there is no presence of any electron withdrawing groups, such as oxygen or nitrogen, or any strongly electron-donating groups such as alkene or alkynes. \n\nTherefore, it is likely that the molecule contains a ring structure with two methyl groups and two methylene groups attached.\n\nThe only molecule that fits this description is m-xylene.\n\n### Start answer ### \nm-Xylene\n### End answer ###',
#        "### Scratchpad ### \nThe chemical formula is C9H18O. The molecule could be an alcohol, an ether, a ketone, or an aldehyde. The HNMR spectrum provides information about the number and type of hydrogen atom environments in the molecule. \n\nLooking at the HNMR data: \n- Peak at 9.77 ppm could suggest an aldehyde group, but it's quite unusual since aldehyde groups often appear around 9-10 ppm in the HNMR and the intensity is quite high indicating multiple hydrogens in this environment. This might be a result from solvent or some impurities.\n- Peaks at 2.444, 2.439, 2.426, 2.421, 2.407, and 2.402 ppm, these are characteristic of -CH2- groups which are next to a carbonyl group or other electron withdrawing groups. The intensity suggests there are multiple such hydrogens.\n- Peaks at 1.667, 1.649, 1.63, 1.612, and 1.594 ppm, these are characteristic of -CH2- groups in the middle of a carbon chain. The intensity suggests there are multiple such hydrogens.\n- Peaks at 1.36, 1.338, 1.302, and 1.29 ppm, these are characteristic of -CH2- groups at the end of a carbon chain or next to an electron donating group. The intensity suggests there are multiple such hydrogens.\n- Peaks at 0.899, 0.895, 0.882, and 0.864 ppm, these are characteristic of -CH3 groups. The intensity suggests there are multiple such hydrogens.\n\nFrom these peak assignments and intensities, the molecule appears to be non-cyclic with a carbonyl group with multiple -CH2- and -CH3 groups. \n\nBased on the chemical formula (C9H18O) and the HNMR data, the structure could be nonanol. \n\n### Start answer ### Nonanol ### End answer ###",
#        "### Scratchpad ### \nThe chemical formula C6H14 indicates that this is an alkane molecule with no double bonds or rings (since those would reduce the number of hydrogens). \n\nLooking at the HNMR data, we notice a large peak at 0.898 ppm, which is indicative of a methyl group (CH3) in an alkane. The integration value of 1000 might imply that this peak corresponds to more than one identical methyl group. \n\nThere are also peaks at 0.797 and 0.808 ppm with integration values of 108 and 116 respectively, these could be other methyl groups. \n\nWe also see peaks at 0.948 and 0.939 ppm with high integration values (130 and 132), which could correspond to methylene groups (CH2). \n\nFrom the formula, we know that there are 14 hydrogens, which means there are six methyl or methylene groups in total. Considering the peaks and integration values, it's reasonable to propose a structure with two methyl groups and four methylene groups.\n\nThen looking at the CNMR data, we see peaks at 14.37, 20.62, 22.68, 27.86, and 41.56 ppm. These values are indicative of carbon atoms in different environments in an alkane - the two lower values likely correspond to the methyl groups at the ends of the chain, while the higher values correspond to the methylene groups in the middle.\n\nPutting this all together, the most likely structure is hexane, a straight chain alkane with two terminal methyl groups and four methylene groups in between.\n### Scratchpad ###\n\n### Start answer ### \nHexane\n### End answer ###",
#        "### Scratchpad ### \nGiven the molecular formula C8H18, we are dealing with an alkane. Alkanes are saturated hydrocarbons, meaning they contain only carbon and hydrogen atoms with single bonds. They are characterized by the general formula CnH2n+2. \n\nNow, let's consider the HNMR spectrum. All of the HNMR peaks are within the range of 0.9-1.2 ppm, which is typical for protons in alkanes. The integral values represent the number of protons that each peak corresponds to. \n\nThe peak with the highest integral value (1000) likely corresponds to the largest number of equivalent protons in the molecule. In the case of alkanes, this would typically be the protons in the middle of a long carbon chain.\n\nThe presence of only one type of carbon in the CNMR spectrum also suggests a symmetrical molecule, as all the carbons are chemically equivalent.\n\nBased on this, we can hypothesize that the molecule is octane, a straight-chain alkane with 8 carbon atoms.\n\n### Start answer ### Octane ### End answer ###",
#        '### Scratchpad ### \nFirstly, taking a look at the molecular formula, C14H14O3, we can determine the degree of unsaturation. There are 12 degrees of unsaturation. \n\nNow, examining the HNMR spectrum:\n\n1. The signal at 7.681 ppm (131 Hz) suggests an aromatic hydrogen. This is supported by the signals at 7.662 ppm (225 Hz), 7.659 ppm (226 Hz), 7.406 ppm (78 Hz), 7.402 ppm (73 Hz), 7.385 ppm (66 Hz), 7.381 ppm (66 Hz), 7.134 ppm (89 Hz), 7.127 ppm (115 Hz), 7.112 ppm (68 Hz), 7.105 ppm (107 Hz), 7.082 ppm (132 Hz), and 7.076 ppm (98 Hz). This accounts for 10 of the 14 hydrogens, leaving 4 hydrogens unaccounted for. \n\n2. The signal at 3.873 ppm (1000 Hz) could be due to a methylene group (-CH2-) next to an oxygen atom, or perhaps a part of an ether or ester group. The signal at 3.857 ppm (71 Hz), 3.839 ppm (65 Hz), and 3.821 ppm (22 Hz) seem to support this interpretation. This accounts for 2 more of the hydrogens, leaving 2 hydrogens unassigned. \n\n3. The signals at 1.577 ppm (363 Hz) and 1.559 ppm (357 Hz) could be due to a methylene group (-CH2-) next to a carbonyl group. This accounts for the remaining 2 hydrogens. \n\nBased on this analysis, it seems that the molecule could be a benzene ring with two substituents: an ester group and a methylene group. The ester group would account for 2 of the oxygens and the carbonyl carbon, while the methylene group would account for the remaining hydrogen and carbon. \n\nUpon looking up such a structure, the molecule appears to be 2-phenylprop-2-enoic acid. \n### Scratchpad ###\n\n### Start answer ### \n2-Phenylprop-2-enoic acid \n### End answer ###',
#        "### Scratchpad ### \nThe chemical formula is C6H10, which indicates that there might be a ring or double bond present in the structure due to unsaturation.\n\nFirstly, we need to understand that the numbers provided for HNMR spectrum are in the format - Chemical Shift, Integration, Multiplicity. \n\nThe HNMR spectrum data:\n\n452.75, 5.056, 248\n451.94, 5.047, 222\n446.44, 4.985, 145\n445.44, 4.974, 202\n444.06, 4.959, 182\n443.13, 4.948, 106\n172.19, 1.923, 933\n171.75, 1.918, 1000\n\nThe chemical shift (in ppm) indicates the type of hydrogen atoms in the molecule. The integration value represents the number of hydrogen atoms that contribute to the peak, and the multiplicity indicates the number of hydrogen atoms on the adjacent carbon atom.\n\nThe peaks at around 450 ppm might be due to machine error or impurity as they are unlikely to occur in organic molecules, so we can ignore them.\n\nThe peaks at 171.75 and 172.19 ppm indicates the presence of hydrogen atoms adjacent to a double bond or a carbonyl group. Since the chemical formula is C6H10 and there is no oxygen, it's more probable that there is a double bond present.\n\nThe integration values suggests that there are two types of hydrogen atoms, each type represented by 5 hydrogen atoms (933+1000 = 1933, when normalized gives approximately 5 H for each peak).\n\nThis suggests that the molecule could be a cyclohexene, which has a six-membered carbon ring and a double bond. However, the presence of only two types of H is a bit puzzling, as cyclohexene would typically have three. \n\nAnother possibility is that the molecule is 1,3-Cyclohexadiene, which has two types of hydrogens - 4 hydrogens adjacent to double bond and 6 hydrogens on the other carbons. This seems like a more appropriate structure.\n\n### Scratchpad ### \n### Start answer ### \n1,3-Cyclohexadiene\n### End answer ###",
#        '### Scratchpad ### \nLooking at the HNMR spectrum, we have multiple peaks, which indicates different types of protons in the molecule. \n\nThe chemical formula C4H8O suggests that our molecule could be an alkene or a cycloalkane. \n\nThe peak at 9.785 ppm would be unusually downfield for an alkene, but it might match a proton on a carbonyl group or an aldehyde proton. \n\nHowever, the integration values on the high ppm side are not consistent with an aldehyde or a carbonyl group, as these would give a singlet peak with integration consistent with one proton. \n\nThe peaks around 2.5 ppm could be due to protons on a carbon next to an oxygen, while the peaks around 1.5 to 2 ppm could be due to protons on the carbon next to an alkene or a carbonyl group. \n\nThe peaks below 1 ppm are likely due to protons on carbons farther away from the functional group. \n\nConsidering the carbon NMR, the peak at 202.8 ppm is indicative of a carbonyl carbon, while the peaks at 45.82 ppm and 15.69 ppm suggest carbons next to or farther from the carbonyl group respectively.\n\nTaking the above into account, the molecule is likely a cycloalkane with an oxygen. The only possible molecule considering the above information and the chemical formula C4H8O is tetrahydrofuran. \n\n### Start answer ### Tetrahydrofuran ### End answer ###',
#        '### Scratchpad ### \nThe chemical formula is C6H6O2, which indicates that the molecule has 6 carbons, 6 hydrogens and 2 oxygens. The presence of 2 oxygens suggests that there might be two carbonyl groups, or an alcohol and an ether group, or a carboxylic acid group in the molecule. \n\nLooking at the HNMR spectrum, the peaks are grouped into several distinct regions. The peak at 9.51ppm is indicative of a proton in a highly deshielded environment, such as the hydrogen in a carboxylic acid group. The peaks in the region of 7.1-7.2ppm suggest the presence of aromatic protons. The presence of multiple peaks in this region with similar intensities suggests that these protons are equivalent, which is consistent with a symmetrical aromatic ring. The peak at 2.42ppm suggests the presence of an alkyl group.\n\nThe intensities of the peaks also provide some clues about the structure of the molecule. The peak at 9.51ppm has an intensity of 737, suggesting that there is only one proton in this environment. The peaks in the 7.1-7.2ppm region have a combined intensity of around 1000, suggesting that there are five protons in this environment. The peak at 2.42ppm has a combined intensity of around 2500, suggesting that there are two protons in this environment.\n\nPutting all these observations together, a plausible structure for the molecule is a benzoic acid, where there is a carboxylic acid group attached to an aromatic ring. The presence of the peak at 2.42ppm suggests that there is also a methyl group attached to the aromatic ring. \n\nConsidering all the above points, the molecule could be p-Toluic acid. p-Toluic acid has a carboxylic acid group and a methyl group attached to opposite sides of an aromatic ring, which is consistent with the NMR data. ### Scratchpad ###\n\n### Start answer ### p-Toluic acid ### End answer ###',
#        '### Scratchpad ### \n\nThe chemical formula is C13H18O2. The HNMR data shows multiple peaks. \n\nGrouping related peaks together, these are the groups:\n\n1. 7.224 ppm, 7.205 ppm, 7.104 ppm, 7.084 ppm (all around the 7 ppm region, possibly aromatic protons)\n2. 3.723 ppm, 3.705 ppm, 3.687 ppm, 3.669 ppm (all around the 3.7 ppm region)\n3. 2.448 ppm, 2.43 ppm (around 2.4 ppm)\n4. 1.871 ppm, 1.854 ppm, 1.837 ppm, 1.82 ppm, 1.803 ppm (all around 1.8 ppm region)\n5. 1.496 ppm, 1.478 ppm (around 1.5 ppm)\n6. 0.898 ppm, 0.882 ppm (around 0.9 ppm)\n\nThe CNMR data shows peaks from 181.35 ppm to 18.15 ppm, indicating a range of carbon environments, from carbonyl carbon (typical in esters, carboxylic acids, ketones) to alkyl carbons. \n\nGiven the formula C13H18O2, we can start by looking at the number of protons and carbons. There are 13 carbons and 18 protons. \n\nConsidering the peak around 7.2 ppm, it is likely an aromatic ring (as C6H5 group). This accounts for 6 carbons and 5 protons. \n\nThe peak around 3.7 ppm corresponds to 3 protons, likely to be next to the oxygen atom (as CH3O group), accounting for 1 carbon and 3 protons. \n\nThe peaks around 2.4 ppm and 1.8 ppm could be methylene groups (as CH2 group), accounting for 2 carbons and 4 protons. \n\nThe peaks around 1.5 ppm could be a methylene group (as CH2 group), accounting for 1 carbon and 2 protons. \n\nThe peaks around 0.9 ppm could be a methyl group (as CH3 group), accounting for 1 carbon and 3 protons. \n\nSo far, we have accounted for 11 carbons and 17 protons. The remaining 2 carbons and 1 proton could be a carbonyl group (as CO group) and a methine group (as CH group), respectively.\n\nThe above groups suggest the chemical structure could be a phenyl ester compound: 2-phenylethyl acetate. \n\n### Scratchpad ###\n\n### Start answer ### 2-phenylethyl acetate ### End answer ###',
#        '### Scratchpad ### \nThe chemical formula of the molecule is C7H7NO which implies that there are 7 Hydrogen atoms, 7 Carbon atoms, and 1 Nitrogen atom present in the molecule. Analyzing the HNMR spectrum, we observe two groups of peaks around 2.8 ppm and 2.7 ppm, indicating the presence of two different types of protons. The fact that the intensities of these two groups of peaks are close to each other suggests that these two types of protons are present in roughly equal amounts.\n\nNext, we notice a large peak at around 1.985 ppm with an intensity of 1000. This suggests the presence of a large group of identical protons, probably part of a methyl group (CH3) or methylene group (CH2), which are common in organic compounds.\n\nLooking at the CNMR spectrum, we notice three peaks at 171.77 ppm, 26.23 ppm, and 22.74 ppm. The peak at 171.77 ppm could correspond to a carbonyl carbon (C=O), which is typical in aldehydes, ketones, carboxylic acids and amides. The other two peaks likely correspond to carbon atoms in different environments - possibly part of an alkyl chain or a ring structure.\n\nTaking all this information into consideration, the molecule could be a derivative of a benzene ring (C6H5-) with a CO group and a NH group attached, which would account for the chemical formula C7H7NO. This structure suggests that the molecule could be an aniline derivative - specifically, it might be a form of aminobenzoic acid or benzoic acid (C6H5COOH) in which one of the hydrogen atoms has been replaced by an amino group (-NH2).\n\n### Start answer ### Benzanilide ### End answer ###',
#        "### Scratchpad ### \n\nGiven the chemical formula C6H12O2, there are 6 carbons, 12 hydrogens, and 2 oxygens. For NMR, the number of peaks in the H NMR often represents the number of different types of protons in the molecule.\n\nLooking at the H NMR data, there are many different peaks, which would suggest a complex molecule. However, the intensity of the peaks is very informative. The peak at 2.04 ppm has an intensity of 1000, which is significantly higher than other peaks, suggesting that these hydrogens are in the same environment.\n\nThe peaks between 0.853 and 1.364 ppm could belong to the hydrogens attached to carbons. These peaks are all relatively close together, suggesting these hydrogens are in similar, but not identical, environments - likely due to being attached to carbons that are in turn attached to other carbons or the oxygen atoms.\n\nThe peaks between 1.406 and 4.139 ppm are likely due to the hydrogens attached to the carbons near the oxygen atoms, due to the deshielding effect of the electronegative oxygen.\n\nGiven that there are 2 oxygen atoms in the molecule, it's possible that we are dealing with a carboxylic acid (COOH) group, which would account for 1 oxygen atom and the proton signal around 4.067-4.139 ppm. The remaining 5 carbons and 11 hydrogens could form a pentyl group (C5H11), which would account for the rest of the H NMR signals. This would give us a molecule of Pentanoic acid. \n\n### Start answer ### Pentanoic acid ### End answer ###",
#        '### Scratchpad ### \n1. Note that the chemical formula is C8H10O2. The molecule contains 8 carbons, 10 hydrogens, and 2 oxygen atoms. \n2. From the HNMR data, we see a variety of peaks. The most intense peak is at 651.81 Hz (7.278 ppm) with 1000 intensity. This suggests that this peak is likely due to the most abundant type of hydrogen in the molecule, possibly a hydrogen atom on a benzene ring. \n3. The peaks at 4.791, 4.739, and 4.71 ppm are all relatively close together and have low intensity. These may represent hydrogen atoms on a carbon atom adjacent to a functional group such as an alcohol or ether. \n4. The peaks at 3.685, 3.64, and 3.595 ppm are also relatively close together and have higher intensity. These may represent hydrogen atoms on a carbon atom that is not directly adjacent to a functional group. \n5. The peak at 3.556 ppm with 90 intensity suggests that there might be a CH3 group.\n6. The chemical shift around 7 indicates the presence of an aromatic ring (benzene) in the molecule. This would account for 6 carbons and 5 hydrogens. \n7. The chemical shift around 4.7 indicates that there might be a methylene group adjacent to the oxygen atom. This would account for 2 hydrogens and 1 carbon.\n8. The chemical shifts around 3.6 suggests the presence of a methylene group not directly adjacent to a functional group. This would account for 2 hydrogens and 1 carbon.\n9. The chemical shift around 3.5 suggests the presence of a methyl group. This would account for the remaining 3 hydrogens and 1 carbon.\n10. The remaining oxygen atom would likely be part of a carbonyl group, such as a ketone or aldehyde, adjacent to the benzene ring.\n11. The remaining carbon atoms and oxygen atom likely form a carbonyl group.\n12. Putting it all together, the molecule is likely a derivative of a benzene ring with a carbonyl group and an ether group attached to it. The most likely structure would be a phenylacetate.\n\n### Start answer ### Phenylacetate ### End answer ###'],
#       dtype=object)

# %%
import re

# Define a function to extract the guess answer
def extract_guess_answer(x):
    match = re.search(r'### Start answer ###\s*(.*?)\s*### End answer ###', x)
    if match:
        return match.group(1)
    else:
        return None  # or any other fallback value you prefer

# Apply the function to create a new column 'guess_answer'
df['guess_answer'] = df['guess'].apply(extract_guess_answer)

# Display the DataFrame with the new 'guess_answer' column
print(df)
# Out:
#     cas_number                                              guess  \
# 0     105-53-3  ### Scratchpad ###\n\nThe molecule is C7H14O2,...
# 1   13475-82-6  ### Scratchpad ### \n\nConsidering the chemica...
# 2      93-58-3  ### Scratchpad ### \n\nThe chemical formula C8...
# 3      52-52-8  ### Scratchpad ###\nThe chemical formula is C6...
# 4      78-78-4  ### Scratchpad ### \nThe chemical formula C5H1...
# 5     591-76-4  ### Scratchpad ### \n\nThe given formula is C7...
# 6     108-38-3  ### Scratchpad ### \nThe molecular formula is ...
# 7     124-19-6  ### Scratchpad ### \nThe chemical formula is C...
# 8     107-83-5  ### Scratchpad ### \nThe chemical formula C6H1...
# 9     540-84-1  ### Scratchpad ### \nGiven the molecular formu...
# 10  22204-53-1  ### Scratchpad ### \nFirstly, taking a look at...
# 11    513-81-5  ### Scratchpad ### \nThe chemical formula is C...
# 12    123-72-8  ### Scratchpad ### \nLooking at the HNMR spect...
# 13    620-02-0  ### Scratchpad ### \nThe chemical formula is C...
# 14  15687-27-1  ### Scratchpad ### \n\nThe chemical formula is...
# 15     79-16-3  ### Scratchpad ### \nThe chemical formula of t...
# 16    123-86-4  ### Scratchpad ### \n\nGiven the chemical form...
# 17     93-56-1  ### Scratchpad ### \n1. Note that the chemical...
#
#                   guess_answer
# 0             Butyl propionate
# 1                     Dodecane
# 2                p-Toluic acid
# 3   2,2,4-Trimethylpentanamide
# 4                      Pentane
# 5        2,2,3-trimethylbutane
# 6                     m-Xylene
# 7                      Nonanol
# 8                       Hexane
# 9                       Octane
# 10   2-Phenylprop-2-enoic acid
# 11          1,3-Cyclohexadiene
# 12             Tetrahydrofuran
# 13               p-Toluic acid
# 14       2-phenylethyl acetate
# 15                 Benzanilide
# 16              Pentanoic acid
# 17               Phenylacetate

# %%
df2=pd.read_csv('CandidateList_HL.csv')

# %%
import pandas as pd

# Your existing code for merging dataframes
# Assuming df and df2 are already defined and populated with your data
merged_df = pd.merge(df, df2, how='left', left_on='cas_number', right_on='CAS')

# Drop the redundant 'CAS' column
merged_df.drop(columns=['CAS'], inplace=True)

# Rename the common name column to 'True answer'
merged_df.rename(columns={'Common name': 'True answer'}, inplace=True)

# Path to save the DataFrame to your Mac desktop
desktop_path = "/Users/username/Desktop/merged_dataframe.csv"  # Replace 'your_username' with your actual username

# Save the DataFrame to the specified path
merged_df.to_csv(desktop_path, index=False)

# Output the merged DataFrame
print(merged_df)
# Out:
#     cas_number                                              guess  \
# 0     105-53-3  ### Scratchpad ###\n\nThe molecule is C7H14O2,...
# 1   13475-82-6  ### Scratchpad ### \n\nConsidering the chemica...
# 2      93-58-3  ### Scratchpad ### \n\nThe chemical formula C8...
# 3      52-52-8  ### Scratchpad ###\nThe chemical formula is C6...
# 4      78-78-4  ### Scratchpad ### \nThe chemical formula C5H1...
# 5     591-76-4  ### Scratchpad ### \n\nThe given formula is C7...
# 6     108-38-3  ### Scratchpad ### \nThe molecular formula is ...
# 7     124-19-6  ### Scratchpad ### \nThe chemical formula is C...
# 8     107-83-5  ### Scratchpad ### \nThe chemical formula C6H1...
# 9     540-84-1  ### Scratchpad ### \nGiven the molecular formu...
# 10  22204-53-1  ### Scratchpad ### \nFirstly, taking a look at...
# 11    513-81-5  ### Scratchpad ### \nThe chemical formula is C...
# 12    123-72-8  ### Scratchpad ### \nLooking at the HNMR spect...
# 13    620-02-0  ### Scratchpad ### \nThe chemical formula is C...
# 14  15687-27-1  ### Scratchpad ### \n\nThe chemical formula is...
# 15     79-16-3  ### Scratchpad ### \nThe chemical formula of t...
# 16    123-86-4  ### Scratchpad ### \n\nGiven the chemical form...
# 17     93-56-1  ### Scratchpad ### \n1. Note that the chemical...
#
#                   guess_answer molecular formula  \
# 0             Butyl propionate           C7H14O2
# 1                     Dodecane            C12H26
# 2                p-Toluic acid            C8H8O2
# 3   2,2,4-Trimethylpentanamide          C6H11NO2
# 4                      Pentane             C5H12
# 5        2,2,3-trimethylbutane             C7H16
# 6                     m-Xylene             C8H10
# 7                      Nonanol           C9H18O
# 8                       Hexane             C6H14
# 9                       Octane            C8H18
# 10   2-Phenylprop-2-enoic acid          C14H14O3
# 11          1,3-Cyclohexadiene             C6H10
# 12             Tetrahydrofuran             C4H8O
# 13               p-Toluic acid            C6H6O2
# 14       2-phenylethyl acetate          C13H18O2
# 15                 Benzanilide            C7H7NO
# 16              Pentanoic acid           C6H12O2
# 17               Phenylacetate           C8H10O2
#
#                               True answer
# 0                        Diethyl malonate
# 1         Heptane, 2,2,4,6,6-pentamethyl-
# 2              Benzoic acid, methyl ester
# 3   Cyclopentanecarboxylic acid, 1-amino-
# 4                       Butane, 2-methyl-
# 5                       Hexane, 2-methyl-
# 6                  Benzene, 1,3-dimethyl-
# 7                                 Nonanol
# 8                      Pentane, 2-methyl-
# 9               Pentane, 2,2,4-trimethyl-
# 10                               Naproxen
# 11           1,3-Butadiene, 2,3-dimethyl-
# 12                                Butanal
# 13       2-Furancarboxaldehyde, 5-methyl-
# 14                              ibuprofen
# 15                   Acetamide, N-methyl-
# 16               Acetic acid, butyl ester
# 17              1,2-Ethanediol, 1-phenyl-

# %%
merged_df.to_csv('merged_df.csv', index=False)

# %%
df
# Out:
#     cas_number                                              guess  \
# 0     105-53-3  ### Scratchpad ###\n\nThe molecule is C7H14O2,...
# 1   13475-82-6  ### Scratchpad ### \n\nConsidering the chemica...
# 2      93-58-3  ### Scratchpad ### \n\nThe chemical formula C8...
# 3      52-52-8  ### Scratchpad ###\nThe chemical formula is C6...
# 4      78-78-4  ### Scratchpad ### \nThe chemical formula C5H1...
# 5     591-76-4  ### Scratchpad ### \n\nThe given formula is C7...
# 6     108-38-3  ### Scratchpad ### \nThe molecular formula is ...
# 7     124-19-6  ### Scratchpad ### \nThe chemical formula is C...
# 8     107-83-5  ### Scratchpad ### \nThe chemical formula C6H1...
# 9     540-84-1  ### Scratchpad ### \nGiven the molecular formu...
# 10  22204-53-1  ### Scratchpad ### \nFirstly, taking a look at...
# 11    513-81-5  ### Scratchpad ### \nThe chemical formula is C...
# 12    123-72-8  ### Scratchpad ### \nLooking at the HNMR spect...
# 13    620-02-0  ### Scratchpad ### \nThe chemical formula is C...
# 14  15687-27-1  ### Scratchpad ### \n\nThe chemical formula is...
# 15     79-16-3  ### Scratchpad ### \nThe chemical formula of t...
# 16    123-86-4  ### Scratchpad ### \n\nGiven the chemical form...
# 17     93-56-1  ### Scratchpad ### \n1. Note that the chemical...
#
#                   guess_answer
# 0             Butyl propionate
# 1                     Dodecane
# 2                p-Toluic acid
# 3   2,2,4-Trimethylpentanamide
# 4                      Pentane
# 5        2,2,3-trimethylbutane
# 6                     m-Xylene
# 7                      Nonanol
# 8                       Hexane
# 9                       Octane
# 10   2-Phenylprop-2-enoic acid
# 11          1,3-Cyclohexadiene
# 12             Tetrahydrofuran
# 13               p-Toluic acid
# 14       2-phenylethyl acetate
# 15                 Benzanilide
# 16              Pentanoic acid
# 17               Phenylacetate
